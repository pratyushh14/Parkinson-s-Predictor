# %%
import numpy as np 
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm 
from sklearn.metrics import accuracy_score

# %%
parkinson_data = pd.read_csv("parkinsons.csv")
parkinson_data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
parkinson_data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
parkinson_data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
parkinson_data['PPE'].mean()
# Out:
# 0.20655164102564103

# %%
parkinson_data['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
parkinson_data.drop('name', axis = 1, inplace=True)

# %%
# group the data based on target variable (status)
parkinson_data.groupby('status',).mean()
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR        HNR  \
# status                    ...
# 0               0.162958  ...  0.013305     0.028511  0.011483  24.678750
# 1               0.321204  ...  0.027600     0.053027  0.029211  20.974048
#
#             RPDE       DFA   spread1   spread2        D2       PPE
# status
# 0       0.442552  0.695716 -6.759264  0.160292  2.154491  0.123017
# 1       0.516816  0.725408 -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %%
X = parkinson_data.drop(['status'], axis=1)
Y = parkinson_data['status']
X.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00370   0.00554     0.01109       0.04374             0.426  ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626  ...
# 2   0.00544   0.00781     0.01633       0.05233             0.482  ...
# 3   0.00502   0.00698     0.01505       0.05492             0.517  ...
# 4   0.00655   0.00908     0.01966       0.06425             0.584  ...
#
#    MDVP:APQ  Shimmer:DDA      NHR     HNR      RPDE       DFA   spread1  \
# ...

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: status, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=2)

# %%
X_train
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 123      182.018       197.173        79.187         0.00842
# 160      114.238       124.393        77.022         0.00581
# 94       157.821       172.975        68.401         0.00358
# 57       117.274       129.916       110.402         0.00752
# 41       184.055       196.537       166.977         0.00258
# ..           ...           ...           ...             ...
# 43       241.404       248.834       232.483         0.00281
# 22       167.930       193.221        79.068         0.00442
# 72       120.080       139.710       111.208         0.00405
# 15       142.167       217.455        83.159         0.00369
# 168      197.569       217.627        90.794         0.00803
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 123           0.00005   0.00506   0.00449     0.01517       0.02503
# 160           0.00005   0.00299   0.00316     0.00896       0.04009
# ...

# %%
X_test
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 10        88.333       112.240        84.072         0.00505
# 79       100.770       115.697        85.545         0.01038
# 164      102.273       142.830        85.902         0.00907
# 142      198.458       219.290       148.691         0.00376
# 186      116.556       592.030        86.228         0.00496
# 133      118.747       123.723       109.836         0.00331
# 35       201.464       210.565       195.708         0.00198
# 137      113.166       130.270       100.673         0.00502
# 25       104.400       206.002        77.968         0.00633
# 2        116.682       131.111       111.555         0.01050
# 12       136.926       159.866       131.276         0.00293
# 128      119.031       127.533       109.216         0.00440
# 144      202.544       241.350       164.168         0.00254
# 3        116.676       137.871       111.366         0.00997
# ...

# %%
# Data Standarisation meaning we want all the data in common range
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
pd.DataFrame(X_train)
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.632396 -0.027311 -0.879850  0.368062  0.144068  0.492807  0.304769
# 1   -1.055127 -0.833370 -0.928478 -0.129978  0.144068 -0.152361 -0.144364
# 2    0.029962 -0.295311 -1.122111 -0.555506 -0.672199 -0.473387 -0.549597
# 3   -0.979540 -0.772202 -0.178741  0.196324  0.416157 -0.152361  0.372307
# 4    0.683112 -0.034355  1.091970 -0.746326 -0.944288 -0.666625 -0.715067
# ..        ...       ...       ...       ...       ...       ...       ...
# 151  2.110934  0.544850  2.563277 -0.702437 -0.944288 -0.594940 -0.627266
# 152  0.281646 -0.071080 -0.882523 -0.395217 -0.400110 -0.398585 -0.377373
# 153 -0.909679 -0.663730 -0.160638 -0.465820 -0.400110 -0.523255 -0.468550
# 154 -0.359777  0.197318 -0.790637 -0.534516 -0.400110 -0.594940 -0.525958
# 155  1.019571  0.199223 -0.619150  0.293642 -0.128021  0.442938  0.301392
#
#            7         8         9   ...        12        13        14  \
# ...

# %%
# model training
model = svm.SVC(kernel='linear')

# %%
# training the model using X_train and Y_train and using this it will find the hyperplane
model.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(Y_train, X_train_prediction)

# %%
training_data_accuracy
# Out:
# 0.9044117647058824

# %%
X_test_prediction = model.predict(X_test)
testing_data_accuracy = accuracy_score(Y_test, X_test_prediction)

# %%
testing_data_accuracy
# Out:
# 0.7966101694915254

# %%
# predictive system
input_data = (162.568, 198.346, 77.63, 0.00502,	0.00003, 0.0028, 0.00253, 0.00841, 0.01791,	0.168, 0.00793,	0.01057, 0.01799, 0.0238, 0.0117, 25.678, 0.427785,	0.723797, -6.635729, 0.209866, 1.957961, 0.135242)


numpy_array = np.asarray(input_data)

input_data_reshaped = numpy_array.reshape(1, -1)

std_data = scaler.transform(input_data_reshaped)

prediction = model.predict(std_data)
# Out:
# C:\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
if (prediction[0] == 1):
    print("The person has Parkinson Disease")
else:
    print("The person does not have Parkinson Disease")
# Out:
# The person has Parkinson Disease

# %%
from sklearn.ensemble import RandomForestClassifier
random = RandomForestClassifier()
random.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
X_train_prediction_2 = random.predict(X_train)
accuracy_2 = accuracy_score(X_train_prediction_2, Y_train)
accuracy_2
# Out:
# 1.0

# %%
X_test_prediction_2 = random.predict(X_test)
accuracy_2 = accuracy_score(X_test_prediction_2, Y_test)
accuracy_2
# Out:
# 0.8135593220338984

# %%
# 162.568, 198.346,	77.63,	0.00502, 0.00003, 0.01791, 0.168, 0.0117, 25.678, 0.427785,	0.723797,	-6.635729,	0.209866,	1.957961,	0.135242
# 198.383, 215.203,	193.104, 0.00212, 0.00001, 0.01263,	0.111, 0.00119,	30.775, 0.465946,	0.738703,	-7.067931,	0.175181,	1.512275,	0.09632

# %%
import pickle

# %%
filename = 'trained_parkinson_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
# loading the model
loaded_model = pickle.load(open('trained_parkinson_model.sav', 'rb'))

# %%
# checking the loaded model
input_data = (162.568, 198.346, 77.63, 0.00502,	0.00003, 0.0028, 0.00253, 0.00841, 0.01791,	0.168, 0.00793,	0.01057, 0.01799, 0.0238, 0.0117, 25.678, 0.427785,	0.723797, -6.635729, 0.209866, 1.957961, 0.135242)


numpy_array = np.asarray(input_data)

input_data_reshaped = numpy_array.reshape(1, -1)

std_data = scaler.transform(input_data_reshaped)

prediction = loaded_model.predict(std_data)

if (prediction[0] == 1):
    print("The person has Parkinson Disease")
else:
    print("The person does not have Parkinson Disease")
# Out:
# The person has Parkinson Disease
# C:\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
filename = 'scaler_model.sav'
pickle.dump(scaler, open(filename, 'wb'))
